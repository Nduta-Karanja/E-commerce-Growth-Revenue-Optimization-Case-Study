# %% [markdown]
# # **E-COMMERSE REVENUE GROWTH OPTIMIZATION CASE STUDY**
# **Author: Nduta Karanja**

# %% [markdown]
# ## 1.INTRODUCTION
#
# **1.1. Problem Statement**
# * **Context:** E-commerce businesses operate in highly competitive environments where small *improvements* in aquisition processes, conversion rates, customer retention, and marketing efficiency can significantly *impact revenue* and *maximise growth*.
#
# * **Business Problem:** This project analyzes a real-world e-commerce dataset to understand how customers move through the *purchase journey*, identify points of *revenue leakage*, and evaluate the effectiveness of marketing and operational performance.
# Identifiable challages leading to revenew leakages include:
#    * High customer drop-off rates before purchase completion
#    * Inefficient marketing spend with unclear ROI
#    * Poor visibility into customer behavior and retention
#    * Delivery delays affecting customer satisfaction
#    * Lack of product and channel-level profitability insights
#
# * **Objective:** *Using a multi-table dataset* covering orders, customers, payments, products, reviews, and delivery performance, this project analyzes a real-world e-commerce dataset to simulate a *Revenue Intelligence system* that connects customer behavior, marketing performance, sales funnel dynamics, and operational efficiency. The goal is to *uncover actionable insights* that drive *revenue growth*, *improve conversion rates*, and *enhance customer retention*.

# %% [markdown]
# Importing core libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# # 2.DATA
#
# **2.1. Data Understanding**
# * Name:Brazilian E-Commerce Public Dataset by Olist
# * Source:Keggle
#
# The dataset has information of 100k orders from 2016 to 2018 made at multiple marketplaces in Brazil.
# This project uses a real-world e-commerce dataset representing a *full marketplace operation*. The dataset includes multiple relational tables that capture the *end-to-end customer journey*, from acquisition and order placement to payment, delivery, and post-purchase feedback.
#
# The data is structured across key entities including orders, customers, order items, payments, products, and reviews. These tables are connected using unique identifiers such as *order_id* and *customer_id*, enabling integrated analysis across the entire revenue lifecycle.
#
# From a business perspective, the dataset allows reconstruction of the full customer journey: *acquisition ~ product interaction ~ purchase ~ payment ~ delivery ~ customer feedback*. This makes it suitable for analyzing conversion funnels, revenue performance, customer behavior, and operational efficiency.
#
# This is real commercial data, it has been anonymised, and references to the companies and partners in the review text have been replaced with the names of Game of Thrones great houses.

# %% [markdown]
# **2.2. Data loading**
